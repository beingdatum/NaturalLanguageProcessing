# %%
import bs4 as bs
import urllib.request
import re
import nltk

scrapped_data = urllib.request.urlopen('https://en.wikipedia.org/wiki/Artificial_intelligence')
article = scrapped_data .read()

parsed_article = bs.BeautifulSoup(article,'lxml')

paragraphs = parsed_article.find_all('p')

article_text = ""

for p in paragraphs:
    article_text += p.text

# %%
# Cleaing the text
processed_article = article_text.lower()
processed_article = re.sub('[^a-zA-Z]', ' ', processed_article )
processed_article = re.sub(r'\s+', ' ', processed_article)

# Preparing the dataset
all_sentences = nltk.sent_tokenize(processed_article)

all_words = [nltk.word_tokenize(sent) for sent in all_sentences]

# Removing Stop Words
from nltk.corpus import stopwords
for i in range(len(all_words)):
    all_words[i] = [w for w in all_words[i] if w not in stopwords.words('english')]

# %%
from gensim.models import Word2Vec

word2vec = Word2Vec(all_words, min_count=2)

# %%
vocabulary = word2vec.wv.vocab
print(vocabulary)
# Out:
# {'computer': <gensim.models.keyedvectors.Vocab object at 0x0000021984CC6DA0>, 'science': <gensim.models.keyedvectors.Vocab object at 0x000002198813D240>, 'artificial': <gensim.models.keyedvectors.Vocab object at 0x000002198813D630>, 'intelligence': <gensim.models.keyedvectors.Vocab object at 0x000002198813D668>, 'ai': <gensim.models.keyedvectors.Vocab object at 0x000002198A925240>, 'sometimes': <gensim.models.keyedvectors.Vocab object at 0x000002198A925278>, 'called': <gensim.models.keyedvectors.Vocab object at 0x000002198A9252B0>, 'machine': <gensim.models.keyedvectors.Vocab object at 0x000002198AABEE48>, 'demonstrated': <gensim.models.keyedvectors.Vocab object at 0x000002198AB542E8>, 'machines': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54358>, 'contrast': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54390>, 'natural': <gensim.models.keyedvectors.Vocab object at 0x000002198AB543C8>, 'displayed': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54400>, 'humans': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54438>, 'leading': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54470>, 'field': <gensim.models.keyedvectors.Vocab object at 0x000002198AB544A8>, 'study': <gensim.models.keyedvectors.Vocab object at 0x000002198AB544E0>, 'intelligent': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54518>, 'agents': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54550>, 'device': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54588>, 'perceives': <gensim.models.keyedvectors.Vocab object at 0x000002198AB545C0>, 'environment': <gensim.models.keyedvectors.Vocab object at 0x000002198AB545F8>, 'takes': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54630>, 'actions': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54668>, 'maximize': <gensim.models.keyedvectors.Vocab object at 0x000002198AB546A0>, 'chance': <gensim.models.keyedvectors.Vocab object at 0x000002198AB546D8>, 'successfully': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54710>, 'achieving': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54748>, 'goals': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54780>, 'term': <gensim.models.keyedvectors.Vocab object at 0x000002198AB547B8>, 'often': <gensim.models.keyedvectors.Vocab object at 0x000002198AB547F0>, 'used': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54828>, 'describe': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54860>, 'computers': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54898>, 'mimic': <gensim.models.keyedvectors.Vocab object at 0x000002198AB548D0>, 'cognitive': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54908>, 'functions': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54940>, 'human': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54978>, 'mind': <gensim.models.keyedvectors.Vocab object at 0x000002198AB549B0>, 'learning': <gensim.models.keyedvectors.Vocab object at 0x000002198AB549E8>, 'problem': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54A20>, 'solving': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54A58>, 'become': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54A90>, 'increasingly': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54AC8>, 'capable': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54B00>, 'tasks': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54B38>, 'considered': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54B70>, 'require': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54BA8>, 'definition': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54BE0>, 'phenomenon': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54C18>, 'known': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54C50>, 'effect': <gensim.models.keyedvectors.Vocab object at 0x000002198AB54C88>, 'done': <gensim.models.key ...

# %%
v1 = word2vec.wv['artificial']

# %%
sim_words = word2vec.wv.most_similar('intelligence')

# %%
sim_words
# Out:
# [('ai', 0.6720988750457764),
#  ('also', 0.6517274379730225),
#  ('machine', 0.6443747282028198),
#  ('research', 0.6392123103141785),
#  ('learning', 0.6277250051498413),
#  ('systems', 0.6245875358581543),
#  ('include', 0.6202447414398193),
#  ('problem', 0.6189254522323608),
#  ('human', 0.6155276298522949),
#  ('many', 0.6154811978340149)]
